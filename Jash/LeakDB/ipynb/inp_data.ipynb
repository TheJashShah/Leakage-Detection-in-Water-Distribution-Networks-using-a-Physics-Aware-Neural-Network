# %%
import pandas as pd
import numpy as np
import os

import csv

for i in range(1, 1000):

    path = f"D:\LeakDB_full_data\Hanoi\Scenario-{i}\Hanoi_CMH_Scenario-{i}.inp"

    csv_path = os.path.join(os.getcwd(), "..", "csv_of_inp", f"Scenario-{i}.csv")

    if (os.path.exists(path)):
        in_pipes_section = False
        data = []
        
        with open(path, "r") as file:
            for line in file:
                line = line.strip()
                
                if not line or line.startswith(";"):
                    continue
                
                if line.startswith("[PIPES]"):
                    in_pipes_section = True
                    continue
                
                elif line.startswith("[") and in_pipes_section:
                    break
                
                if in_pipes_section:
                    parts = line.split()
                    
                    if len(parts) >= 6:
                        pipe_id, node1, node2, length, diameter, roughness = parts[:6]
                        data.append([pipe_id, node1, node2, length, diameter, roughness])
                        
        with open(csv_path, "w", newline="") as f:
            writer = csv.writer(f)
            writer.writerow(["pipe_id", "node1", "node2", "length", "diameter", "roughness"])
            writer.writerows(data)
            
        print(f"Extracted inp data of Scenario-{i} to csv.")

    else:
        print(f"Scenario-{i} could not be found.")
# Out:
# Extracted inp data of Scenario-1 to csv.
# Extracted inp data of Scenario-2 to csv.
# Extracted inp data of Scenario-3 to csv.
# Extracted inp data of Scenario-4 to csv.
# Extracted inp data of Scenario-5 to csv.
# Extracted inp data of Scenario-6 to csv.
# Extracted inp data of Scenario-7 to csv.
# Extracted inp data of Scenario-8 to csv.
# Extracted inp data of Scenario-9 to csv.
# Extracted inp data of Scenario-10 to csv.
# Extracted inp data of Scenario-11 to csv.
# Extracted inp data of Scenario-12 to csv.
# Extracted inp data of Scenario-13 to csv.
# Extracted inp data of Scenario-14 to csv.
# Extracted inp data of Scenario-15 to csv.
# Extracted inp data of Scenario-16 to csv.
# Extracted inp data of Scenario-17 to csv.
# Extracted inp data of Scenario-18 to csv.
# Extracted inp data of Scenario-19 to csv.
# Extracted inp data of Scenario-20 to csv.
# Extracted inp data of Scenario-21 to csv.
# Extracted inp data of Scenario-22 to csv.
# Extracted inp data of Scenario-23 to csv.
# Extracted inp data of Scenario-24 to csv.
# Extracted inp data of Scenario-25 to csv.
# Extracted inp data of Scenario-26 to csv.
# Extracted inp data of Scenario-27 to csv.
# Extracted inp data of Scenario-28 to csv.
# Extracted inp data of Scenario-29 to csv.
# Extracted inp data of Scenario-30 to csv.
# Extracted inp data of Scenario-31 to csv.
# Extracted inp data of Scenario-32 to csv.
# Extracted inp data of Scenario-33 to csv.
# Extracted inp data of Scenario-34 to csv.
# Extracted inp data of Scenario-35 to csv.
# Extracted inp data of Scenario-36 to csv.
# Extracted inp data of Scenario-37 to csv.
# Extracted inp data of Scenario-38 to csv.
# Extracted inp data of Scenario-39 to csv.
# Extracted inp data of Scenario-40 to csv.
# Extracted inp data of Scenario-41 to csv.
# Extracted inp data of Scenario-42 to csv.
# Extracted inp data of Scenario-43 to csv.
# Extracted inp data of Scenario-44 to csv.
# Extracted inp data of Scenario-45 to csv.
# Extracted inp data of Scenario-46 to csv.
# Extracted inp data of Scenario-47 to csv.
# Extracted inp data of Scenario-48 to csv.
# Extracted inp data of Scenario-49 to csv.
# Extracted inp data of Scenario-50 to csv.
# Extracted inp data of Scenario-51 to csv.
# Extracted inp data of Scenario-52 to csv.
# Extracted inp data of Scenario-53 to csv.
# Extracted inp data of Scenario-54 to csv.
# Extracted inp data of Scenario-55 to csv.
# Extracted inp data of Scenario-56 to csv.
# Extracted inp data of Scenario-57 to csv.
# Extracted inp data of Scenario-58 to csv.
# Extracted inp data of Scenario-59 to csv.
# Extracted inp data of Scenario-60 to csv.
# Extracted inp data of Scenario-61 to csv.
# Extracted inp data of Scenario-62 to csv.
# Extracted inp data of Scenario-63 to csv.
# Extracted inp data of Scenario-64 to csv.
# Extracted inp data of Scenario-65 to csv.
# Extracted inp data of Scenario-66 to csv.
# Extracted inp data of Scenario-67 to csv.
# Extracted inp data of Scenario-68 to csv.
# Extracted inp data of Scenario-69 to csv.
# Extracted inp data of Scenario-70 to csv.
# Extracted inp data of Scenario-71 to csv.
# Extracted inp data of Scenario-72 to csv.
# Extracted inp data of Scenario-73 to csv.
# Extracted inp data of Scenario-74 to csv.
# Extracted inp data of Scenario-75 to csv.
# Extracted inp data of Scenario-76 to csv.
# Extracted inp data of Scenario-77 to csv.
# Extracted inp data of Scenario-78 to csv.
# Extracted inp data of Scenario-79 to csv.
# Extracted inp data of Scenario-80 to csv.
# Extracted inp data of Scenario-81 to csv.
# Extracted inp data of Scenario-82 to csv.
# Extracted inp data of Scenario-83 to csv.
# Extracted inp data of Scenario-84 to csv.
# Extracted inp data of Scenario-85 to csv.
# Extracted inp data of Scenario-86 to csv.
# Extracted inp data of Scenario-87 to csv.
# Extracted inp data of Scenario-88 to csv.
# Extracted inp data of Scenario-89 to csv.
# Extracted inp data of Scenario-90 to csv.
# Extracted inp data of Scenario-91 to csv.
# Extracted inp data of Scenario-92 to csv.
# Extracted inp data of Scenario-93 to csv.
# Extracted inp data of Scenario-94 to csv.
# Extracted inp data of Scenario-95 to csv.
# Extracted inp data of Scenario-96 to csv.
# Extracted inp data of Scenario-97 to csv.
# Extracted inp data of Scenario-98 to csv.
# Extracted inp data of Scenario-99 to csv.
# Extracted inp data of Scenario-100 to csv.
# Extracted inp data of Scenario-101 to csv.
# Extracted inp data of Scenario-102 to csv.
# Extracted inp data of Scenario-103 to csv.
# Extracted inp data of Scenario-104 to csv.
# Extracted inp data of Scenario-105 to csv.
# Extracted inp data of Scenario-106 to csv.
# Extracted inp data of Scenario-107 to csv.
# Extracted inp data of Scenario-108 to csv.
# Extracted inp data of Scenario-109 to csv.
# Extracted inp data of Scenario-110 to csv.
# Extracted inp data of Scenario-111 to csv.
# Extracted inp data of Scenario-112 to csv.
# Extracted inp data of Scenario-113 to csv.
# Extracted inp data of Scenario-114 to csv.
# Extracted inp data of Scenario-115 to csv.
# Extracted inp data of Scenario-116 to csv.
# Extracted inp data of Scenario-117 to csv.
# Extracted inp data of Scenario-118 to csv.
# Extracted inp data of Scenario-119 to csv.
# Extracted inp data of Scenario-120 to csv.
# Extracted inp data of Scenario-121 to csv.
# Extracted inp data of Scenario-122 to csv.
# Extracted inp data of Scenario-123 to csv.
# Extracted inp data of Scenario-124 to csv.
# Extracted inp data of Scenario-125 to csv.
# Extracted inp data of Scenario-126 to csv.
# Extracted inp data of Scenario-127 to csv.
# Extracted inp data of Scenario-128 to csv.
# Extracted inp data of Scenario-129 to csv.
# Extracted inp data of Scenario-130 to csv.
# Extracted inp data of Scenario-131 to csv.
# Extracted inp data of Scenario-132 to csv.
# Extracted inp data of Scenario-133 to csv.
# Extracted inp data of Scenario-134 to csv.
# Extracted inp data of Scenario-135 to csv.
# Extracted inp data of Scenario-136 to csv.
# Extracted inp data of Scenario-137 to csv.
# Extracted inp data of Scenario-138 to csv.
# Extracted inp data of Scenario-139 to csv.
# Extracted inp data of Scenario-140 to csv.
# Extracted inp data of Scenario-141 to csv.
# Extracted inp data of Scenario-142 to csv.
# Extracted inp data of Scenario-143 to csv.
# Extracted inp data of Scenario-144 to csv.
# Extracted inp data of Scenario-145 to csv.
# Extracted inp data of Scenario-146 to csv.
# Extracted inp data of Scenario-147 to csv.
# Extracted inp data of Scenario-148 to csv.
# Extracted inp data of Scenario-149 to csv.
# Extracted inp data of Scenario-150 to csv.
# Extracted inp data of Scenario-151 to csv.
# Extracted inp data of Scenario-152 to csv.
# Extracted inp data of Scenario-153 to csv.
# Extracted inp data of Scenario-154 to csv.
# Extracted inp data of Scenario-155 to csv.
# Extracted inp data of Scenario-156 to csv.
# Extracted inp data of Scenario-157 to csv.
# Extracted inp data of Scenario-158 to csv.
# Extracted inp data of Scenario-159 to csv.
# Extracted inp data of Scenario-160 to csv.
# Extracted inp data of Scenario-161 to csv.
# Extracted inp data of Scenario-162 to csv.
# Extracted inp data of Scenario-163 to csv.
# Extracted inp data of Scenario-164 to csv.
# Extracted inp data of Scenario-165 to csv.
# Extracted inp data of Scenario-166 to csv.
# Extracted inp data of Scenario-167 to csv.
# Extracted inp data of Scenario-168 to csv.
# Extracted inp data of Scenario-169 to csv.
# Extracted inp data of Scenario-170 to csv.
# Extracted inp data of Scenario-171 to csv.
# Extracted inp data of Scenario-172 to csv.
# Extracted inp data of Scenario-173 to csv.
# Extracted inp data of Scenario-174 to csv.
# Extracted inp data of Scenario-175 to csv.
# Extracted inp data of Scenario-176 to csv.
# Extracted inp data of Scenario-177 to csv.
# Extracted inp data of Scenario-178 to csv.
# Extracted inp data of Scenario-179 to csv.
# Extracted inp data of Scenario-180 to csv.
# Extracted inp data of Scenario-181 to csv.
# Extracted inp data of Scenario-182 to csv.
# Extracted inp data of Scenario-183 to csv.
# Extracted inp data of Scenario-184 to csv.
# Extracted inp data of Scenario-185 to csv.
# Extracted inp data of Scenario-186 to csv.
# Extracted inp data of Scenario-187 to csv.
# Extracted inp data of Scenario-188 to csv.
# Extracted inp data of Scenario-189 to csv.
# Extracted inp data of Scenario-190 to csv.
# Extracted inp data of Scenario-191 to csv.
# Extracted inp data of Scenario-192 to csv.
# Extracted inp data of Scenario-193 to csv.
# Extracted inp data of Scenario-194 to csv.
# Extracted inp data of Scenario-195 to csv.
# Extracted inp data of Scenario-196 to csv.
# Extracted inp data of Scenario-197 to csv.
# Extracted inp data of Scenario-198 to csv.
# Extracted inp data of Scenario-199 to csv.
# Extracted inp data of Scenario-200 to csv.
# Extracted inp data of Scenario-201 to csv.
# Extracted inp data of Scenario-202 to csv.
# Extracted inp data of Scenario-203 to csv.
# Extracted inp data of Scenario-204 to csv.
# Extracted inp data of Scenario-205 to csv.
# Extracted inp data of Scenario-206 to csv.
# Extracted inp data of Scenario-207 to csv.
# Extracted inp data of Scenario-208 to csv.
# Extracted inp data of Scenario-209 to csv.
# Extracted inp data of Scenario-210 to csv.
# Extracted inp data of Scenario-211 to csv.
# Extracted inp data of Scenario-212 to csv.
# Extracted inp data of Scenario-213 to csv.
# Extracted inp data of Scenario-214 to csv.
# Extracted inp data of Scenario-215 to csv.
# Extracted inp data of Scenario-216 to csv.
# Extracted inp data of Scenario-217 to csv.
# Extracted inp data of Scenario-218 to csv.
# Extracted inp data of Scenario-219 to csv.
# Extracted inp data of Scenario-220 to csv.
# Extracted inp data of Scenario-221 to csv.
# Extracted inp data of Scenario-222 to csv.
# Extracted inp data of Scenario-223 to csv.
# Extracted inp data of Scenario-224 to csv.
# Extracted inp data of Scenario-225 to csv.
# Extracted inp data of Scenario-226 to csv.
# Extracted inp data of Scenario-227 to csv.
# Extracted inp data of Scenario-228 to csv.
# Extracted inp data of Scenario-229 to csv.
# Extracted inp data of Scenario-230 to csv.
# Extracted inp data of Scenario-231 to csv.
# Extracted inp data of Scenario-232 to csv.
# Extracted inp data of Scenario-233 to csv.
# Extracted inp data of Scenario-234 to csv.
# Extracted inp data of Scenario-235 to csv.
# Extracted inp data of Scenario-236 to csv.
# Extracted inp data of Scenario-237 to csv.
# Extracted inp data of Scenario-238 to csv.
# Extracted inp data of Scenario-239 to csv.
# Extracted inp data of Scenario-240 to csv.
# Extracted inp data of Scenario-241 to csv.
# Extracted inp data of Scenario-242 to csv.
# Extracted inp data of Scenario-243 to csv.
# Extracted inp data of Scenario-244 to csv.
# Extracted inp data of Scenario-245 to csv.
# Extracted inp data of Scenario-246 to csv.
# Extracted inp data of Scenario-247 to csv.
# Extracted inp data of Scenario-248 to csv.
# Extracted inp data of Scenario-249 to csv.
# Extracted inp data of Scenario-250 to csv.
# Extracted inp data of Scenario-251 to csv.
# Extracted inp data of Scenario-252 to csv.
# Extracted inp data of Scenario-253 to csv.
# Extracted inp data of Scenario-254 to csv.
# Extracted inp data of Scenario-255 to csv.
# Extracted inp data of Scenario-256 to csv.
# Extracted inp data of Scenario-257 to csv.
# Extracted inp data of Scenario-258 to csv.
# Extracted inp data of Scenario-259 to csv.
# Extracted inp data of Scenario-260 to csv.
# Extracted inp data of Scenario-261 to csv.
# Extracted inp data of Scenario-262 to csv.
# Extracted inp data of Scenario-263 to csv.
# Extracted inp data of Scenario-264 to csv.
# Extracted inp data of Scenario-265 to csv.
# Extracted inp data of Scenario-266 to csv.
# Extracted inp data of Scenario-267 to csv.
# Extracted inp data of Scenario-268 to csv.
# Extracted inp data of Scenario-269 to csv.
# Extracted inp data of Scenario-270 to csv.
# Extracted inp data of Scenario-271 to csv.
# Extracted inp data of Scenario-272 to csv.
# Extracted inp data of Scenario-273 to csv.
# Extracted inp data of Scenario-274 to csv.
# Extracted inp data of Scenario-275 to csv.
# Extracted inp data of Scenario-276 to csv.
# Extracted inp data of Scenario-277 to csv.
# Extracted inp data of Scenario-278 to csv.
# Extracted inp data of Scenario-279 to csv.
# Extracted inp data of Scenario-280 to csv.
# Extracted inp data of Scenario-281 to csv.
# Extracted inp data of Scenario-282 to csv.
# Extracted inp data of Scenario-283 to csv.
# Extracted inp data of Scenario-284 to csv.
# Extracted inp data of Scenario-285 to csv.
# Extracted inp data of Scenario-286 to csv.
# Extracted inp data of Scenario-287 to csv.
# Extracted inp data of Scenario-288 to csv.
# Extracted inp data of Scenario-289 to csv.
# Extracted inp data of Scenario-290 to csv.
# Extracted inp data of Scenario-291 to csv.
# Extracted inp data of Scenario-292 to csv.
# Extracted inp data of Scenario-293 to csv.
# Extracted inp data of Scenario-294 to csv.
# Extracted inp data of Scenario-295 to csv.
# Extracted inp data of Scenario-296 to csv.
# Extracted inp data of Scenario-297 to csv.
# Extracted inp data of Scenario-298 to csv.
# Extracted inp data of Scenario-299 to csv.
# Extracted inp data of Scenario-300 to csv.
# Extracted inp data of Scenario-301 to csv.
# Extracted inp data of Scenario-302 to csv.
# Extracted inp data of Scenario-303 to csv.
# Extracted inp data of Scenario-304 to csv.
# Extracted inp data of Scenario-305 to csv.
# Extracted inp data of Scenario-306 to csv.
# Extracted inp data of Scenario-307 to csv.
# Extracted inp data of Scenario-308 to csv.
# Extracted inp data of Scenario-309 to csv.
# Extracted inp data of Scenario-310 to csv.
# Extracted inp data of Scenario-311 to csv.
# Extracted inp data of Scenario-312 to csv.
# Extracted inp data of Scenario-313 to csv.
# Extracted inp data of Scenario-314 to csv.
# Extracted inp data of Scenario-315 to csv.
# Extracted inp data of Scenario-316 to csv.
# Extracted inp data of Scenario-317 to csv.
# Extracted inp data of Scenario-318 to csv.
# Extracted inp data of Scenario-319 to csv.
# Extracted inp data of Scenario-320 to csv.
# Extracted inp data of Scenario-321 to csv.
# Extracted inp data of Scenario-322 to csv.
# Extracted inp data of Scenario-323 to csv.
# Extracted inp data of Scenario-324 to csv.
# Extracted inp data of Scenario-325 to csv.
# Extracted inp data of Scenario-326 to csv.
# Extracted inp data of Scenario-327 to csv.
# Extracted inp data of Scenario-328 to csv.
# Extracted inp data of Scenario-329 to csv.
# Extracted inp data of Scenario-330 to csv.
# Extracted inp data of Scenario-331 to csv.
# Extracted inp data of Scenario-332 to csv.
# Extracted inp data of Scenario-333 to csv.
# Extracted inp data of Scenario-334 to csv.
# Extracted inp data of Scenario-335 to csv.
# Extracted inp data of Scenario-336 to csv.
# Extracted inp data of Scenario-337 to csv.
# Extracted inp data of Scenario-338 to csv.
# Extracted inp data of Scenario-339 to csv.
# Extracted inp data of Scenario-340 to csv.
# Extracted inp data of Scenario-341 to csv.
# Extracted inp data of Scenario-342 to csv.
# Extracted inp data of Scenario-343 to csv.
# Extracted inp data of Scenario-344 to csv.
# Extracted inp data of Scenario-345 to csv.
# Extracted inp data of Scenario-346 to csv.
# Extracted inp data of Scenario-347 to csv.
# Extracted inp data of Scenario-348 to csv.
# Extracted inp data of Scenario-349 to csv.
# Extracted inp data of Scenario-350 to csv.
# Extracted inp data of Scenario-351 to csv.
# Scenario-352 could not be found.
# Scenario-353 could not be found.
# Scenario-354 could not be found.
# Extracted inp data of Scenario-355 to csv.
# Extracted inp data of Scenario-356 to csv.
# Extracted inp data of Scenario-357 to csv.
# Extracted inp data of Scenario-358 to csv.
# Extracted inp data of Scenario-359 to csv.
# Extracted inp data of Scenario-360 to csv.
# Extracted inp data of Scenario-361 to csv.
# Extracted inp data of Scenario-362 to csv.
# Extracted inp data of Scenario-363 to csv.
# Extracted inp data of Scenario-364 to csv.
# Extracted inp data of Scenario-365 to csv.
# Extracted inp data of Scenario-366 to csv.
# Extracted inp data of Scenario-367 to csv.
# Extracted inp data of Scenario-368 to csv.
# Extracted inp data of Scenario-369 to csv.
# Extracted inp data of Scenario-370 to csv.
# Extracted inp data of Scenario-371 to csv.
# Extracted inp data of Scenario-372 to csv.
# Extracted inp data of Scenario-373 to csv.
# Extracted inp data of Scenario-374 to csv.
# Extracted inp data of Scenario-375 to csv.
# Extracted inp data of Scenario-376 to csv.
# Extracted inp data of Scenario-377 to csv.
# Extracted inp data of Scenario-378 to csv.
# Extracted inp data of Scenario-379 to csv.
# Extracted inp data of Scenario-380 to csv.
# Extracted inp data of Scenario-381 to csv.
# Extracted inp data of Scenario-382 to csv.
# Extracted inp data of Scenario-383 to csv.
# Extracted inp data of Scenario-384 to csv.
# Extracted inp data of Scenario-385 to csv.
# Extracted inp data of Scenario-386 to csv.
# Extracted inp data of Scenario-387 to csv.
# Extracted inp data of Scenario-388 to csv.
# Scenario-389 could not be found.
# Extracted inp data of Scenario-390 to csv.
# Extracted inp data of Scenario-391 to csv.
# Extracted inp data of Scenario-392 to csv.
# Extracted inp data of Scenario-393 to csv.
# Extracted inp data of Scenario-394 to csv.
# Extracted inp data of Scenario-395 to csv.
# Extracted inp data of Scenario-396 to csv.
# Extracted inp data of Scenario-397 to csv.
# Extracted inp data of Scenario-398 to csv.
# Extracted inp data of Scenario-399 to csv.
# Extracted inp data of Scenario-400 to csv.
# Scenario-401 could not be found.
# Extracted inp data of Scenario-402 to csv.
# Extracted inp data of Scenario-403 to csv.
# Extracted inp data of Scenario-404 to csv.
# Extracted inp data of Scenario-405 to csv.
# Extracted inp data of Scenario-406 to csv.
# Extracted inp data of Scenario-407 to csv.
# Scenario-408 could not be found.
# Extracted inp data of Scenario-409 to csv.
# Extracted inp data of Scenario-410 to csv.
# Extracted inp data of Scenario-411 to csv.
# Extracted inp data of Scenario-412 to csv.
# Extracted inp data of Scenario-413 to csv.
# Extracted inp data of Scenario-414 to csv.
# Extracted inp data of Scenario-415 to csv.
# Extracted inp data of Scenario-416 to csv.
# Extracted inp data of Scenario-417 to csv.
# Extracted inp data of Scenario-418 to csv.
# Extracted inp data of Scenario-419 to csv.
# Extracted inp data of Scenario-420 to csv.
# Extracted inp data of Scenario-421 to csv.
# Extracted inp data of Scenario-422 to csv.
# Extracted inp data of Scenario-423 to csv.
# Extracted inp data of Scenario-424 to csv.
# Extracted inp data of Scenario-425 to csv.
# Extracted inp data of Scenario-426 to csv.
# Extracted inp data of Scenario-427 to csv.
# Extracted inp data of Scenario-428 to csv.
# Extracted inp data of Scenario-429 to csv.
# Extracted inp data of Scenario-430 to csv.
# Extracted inp data of Scenario-431 to csv.
# Extracted inp data of Scenario-432 to csv.
# Extracted inp data of Scenario-433 to csv.
# Extracted inp data of Scenario-434 to csv.
# Extracted inp data of Scenario-435 to csv.
# Extracted inp data of Scenario-436 to csv.
# Extracted inp data of Scenario-437 to csv.
# Extracted inp data of Scenario-438 to csv.
# Extracted inp data of Scenario-439 to csv.
# Extracted inp data of Scenario-440 to csv.
# Extracted inp data of Scenario-441 to csv.
# Extracted inp data of Scenario-442 to csv.
# Extracted inp data of Scenario-443 to csv.
# Extracted inp data of Scenario-444 to csv.
# Scenario-445 could not be found.
# Extracted inp data of Scenario-446 to csv.
# Scenario-447 could not be found.
# Scenario-448 could not be found.
# Scenario-449 could not be found.
# Extracted inp data of Scenario-450 to csv.
# Extracted inp data of Scenario-451 to csv.
# Extracted inp data of Scenario-452 to csv.
# Extracted inp data of Scenario-453 to csv.
# Extracted inp data of Scenario-454 to csv.
# Extracted inp data of Scenario-455 to csv.
# Extracted inp data of Scenario-456 to csv.
# Extracted inp data of Scenario-457 to csv.
# Scenario-458 could not be found.
# Extracted inp data of Scenario-459 to csv.
# Extracted inp data of Scenario-460 to csv.
# Extracted inp data of Scenario-461 to csv.
# Extracted inp data of Scenario-462 to csv.
# Scenario-463 could not be found.
# Extracted inp data of Scenario-464 to csv.
# Extracted inp data of Scenario-465 to csv.
# Scenario-466 could not be found.
# Extracted inp data of Scenario-467 to csv.
# Extracted inp data of Scenario-468 to csv.
# Extracted inp data of Scenario-469 to csv.
# Extracted inp data of Scenario-470 to csv.
# Extracted inp data of Scenario-471 to csv.
# Scenario-472 could not be found.
# Extracted inp data of Scenario-473 to csv.
# Extracted inp data of Scenario-474 to csv.
# Extracted inp data of Scenario-475 to csv.
# Scenario-476 could not be found.
# Extracted inp data of Scenario-477 to csv.
# Scenario-478 could not be found.
# Extracted inp data of Scenario-479 to csv.
# Extracted inp data of Scenario-480 to csv.
# Extracted inp data of Scenario-481 to csv.
# Extracted inp data of Scenario-482 to csv.
# Extracted inp data of Scenario-483 to csv.
# Scenario-484 could not be found.
# Extracted inp data of Scenario-485 to csv.
# Extracted inp data of Scenario-486 to csv.
# Scenario-487 could not be found.
# Extracted inp data of Scenario-488 to csv.
# Extracted inp data of Scenario-489 to csv.
# Extracted inp data of Scenario-490 to csv.
# Scenario-491 could not be found.
# Extracted inp data of Scenario-492 to csv.
# Extracted inp data of Scenario-493 to csv.
# Extracted inp data of Scenario-494 to csv.
# Extracted inp data of Scenario-495 to csv.
# Extracted inp data of Scenario-496 to csv.
# Extracted inp data of Scenario-497 to csv.
# Extracted inp data of Scenario-498 to csv.
# Extracted inp data of Scenario-499 to csv.
# Extracted inp data of Scenario-500 to csv.
# Extracted inp data of Scenario-501 to csv.
# Extracted inp data of Scenario-502 to csv.
# Scenario-503 could not be found.
# Extracted inp data of Scenario-504 to csv.
# Extracted inp data of Scenario-505 to csv.
# Extracted inp data of Scenario-506 to csv.
# Extracted inp data of Scenario-507 to csv.
# Extracted inp data of Scenario-508 to csv.
# Extracted inp data of Scenario-509 to csv.
# Extracted inp data of Scenario-510 to csv.
# Extracted inp data of Scenario-511 to csv.
# Scenario-512 could not be found.
# Extracted inp data of Scenario-513 to csv.
# Extracted inp data of Scenario-514 to csv.
# Extracted inp data of Scenario-515 to csv.
# Extracted inp data of Scenario-516 to csv.
# Extracted inp data of Scenario-517 to csv.
# Extracted inp data of Scenario-518 to csv.
# Extracted inp data of Scenario-519 to csv.
# Extracted inp data of Scenario-520 to csv.
# Extracted inp data of Scenario-521 to csv.
# Extracted inp data of Scenario-522 to csv.
# Extracted inp data of Scenario-523 to csv.
# Extracted inp data of Scenario-524 to csv.
# Extracted inp data of Scenario-525 to csv.
# Extracted inp data of Scenario-526 to csv.
# Extracted inp data of Scenario-527 to csv.
# Extracted inp data of Scenario-528 to csv.
# Scenario-529 could not be found.
# Extracted inp data of Scenario-530 to csv.
# Extracted inp data of Scenario-531 to csv.
# Extracted inp data of Scenario-532 to csv.
# Extracted inp data of Scenario-533 to csv.
# Extracted inp data of Scenario-534 to csv.
# Extracted inp data of Scenario-535 to csv.
# Extracted inp data of Scenario-536 to csv.
# Extracted inp data of Scenario-537 to csv.
# Extracted inp data of Scenario-538 to csv.
# Extracted inp data of Scenario-539 to csv.
# Extracted inp data of Scenario-540 to csv.
# Extracted inp data of Scenario-541 to csv.
# Extracted inp data of Scenario-542 to csv.
# Extracted inp data of Scenario-543 to csv.
# Extracted inp data of Scenario-544 to csv.
# Extracted inp data of Scenario-545 to csv.
# Extracted inp data of Scenario-546 to csv.
# Extracted inp data of Scenario-547 to csv.
# Extracted inp data of Scenario-548 to csv.
# Scenario-549 could not be found.
# Extracted inp data of Scenario-550 to csv.
# Extracted inp data of Scenario-551 to csv.
# Extracted inp data of Scenario-552 to csv.
# Extracted inp data of Scenario-553 to csv.
# Scenario-554 could not be found.
# Scenario-555 could not be found.
# Extracted inp data of Scenario-556 to csv.
# Extracted inp data of Scenario-557 to csv.
# Extracted inp data of Scenario-558 to csv.
# Extracted inp data of Scenario-559 to csv.
# Extracted inp data of Scenario-560 to csv.
# Extracted inp data of Scenario-561 to csv.
# Extracted inp data of Scenario-562 to csv.
# Scenario-563 could not be found.
# Extracted inp data of Scenario-564 to csv.
# Extracted inp data of Scenario-565 to csv.
# Extracted inp data of Scenario-566 to csv.
# Extracted inp data of Scenario-567 to csv.
# Extracted inp data of Scenario-568 to csv.
# Extracted inp data of Scenario-569 to csv.
# Extracted inp data of Scenario-570 to csv.
# Extracted inp data of Scenario-571 to csv.
# Extracted inp data of Scenario-572 to csv.
# Extracted inp data of Scenario-573 to csv.
# Extracted inp data of Scenario-574 to csv.
# Extracted inp data of Scenario-575 to csv.
# Extracted inp data of Scenario-576 to csv.
# Extracted inp data of Scenario-577 to csv.
# Extracted inp data of Scenario-578 to csv.
# Extracted inp data of Scenario-579 to csv.
# Extracted inp data of Scenario-580 to csv.
# Extracted inp data of Scenario-581 to csv.
# Extracted inp data of Scenario-582 to csv.
# Extracted inp data of Scenario-583 to csv.
# Scenario-584 could not be found.
# Extracted inp data of Scenario-585 to csv.
# Extracted inp data of Scenario-586 to csv.
# Extracted inp data of Scenario-587 to csv.
# Extracted inp data of Scenario-588 to csv.
# Extracted inp data of Scenario-589 to csv.
# Extracted inp data of Scenario-590 to csv.
# Extracted inp data of Scenario-591 to csv.
# Extracted inp data of Scenario-592 to csv.
# Extracted inp data of Scenario-593 to csv.
# Extracted inp data of Scenario-594 to csv.
# Extracted inp data of Scenario-595 to csv.
# Scenario-596 could not be found.
# Extracted inp data of Scenario-597 to csv.
# Extracted inp data of Scenario-598 to csv.
# Extracted inp data of Scenario-599 to csv.
# Extracted inp data of Scenario-600 to csv.
# Extracted inp data of Scenario-601 to csv.
# Extracted inp data of Scenario-602 to csv.
# Extracted inp data of Scenario-603 to csv.
# Extracted inp data of Scenario-604 to csv.
# Extracted inp data of Scenario-605 to csv.
# Extracted inp data of Scenario-606 to csv.
# Scenario-607 could not be found.
# Extracted inp data of Scenario-608 to csv.
# Extracted inp data of Scenario-609 to csv.
# Extracted inp data of Scenario-610 to csv.
# Extracted inp data of Scenario-611 to csv.
# Extracted inp data of Scenario-612 to csv.
# Extracted inp data of Scenario-613 to csv.
# Extracted inp data of Scenario-614 to csv.
# Extracted inp data of Scenario-615 to csv.
# Extracted inp data of Scenario-616 to csv.
# Extracted inp data of Scenario-617 to csv.
# Extracted inp data of Scenario-618 to csv.
# Extracted inp data of Scenario-619 to csv.
# Extracted inp data of Scenario-620 to csv.
# Extracted inp data of Scenario-621 to csv.
# Extracted inp data of Scenario-622 to csv.
# Extracted inp data of Scenario-623 to csv.
# Extracted inp data of Scenario-624 to csv.
# Extracted inp data of Scenario-625 to csv.
# Extracted inp data of Scenario-626 to csv.
# Extracted inp data of Scenario-627 to csv.
# Extracted inp data of Scenario-628 to csv.
# Extracted inp data of Scenario-629 to csv.
# Extracted inp data of Scenario-630 to csv.
# Extracted inp data of Scenario-631 to csv.
# Extracted inp data of Scenario-632 to csv.
# Extracted inp data of Scenario-633 to csv.
# Extracted inp data of Scenario-634 to csv.
# Extracted inp data of Scenario-635 to csv.
# Extracted inp data of Scenario-636 to csv.
# Extracted inp data of Scenario-637 to csv.
# Extracted inp data of Scenario-638 to csv.
# Extracted inp data of Scenario-639 to csv.
# Extracted inp data of Scenario-640 to csv.
# Extracted inp data of Scenario-641 to csv.
# Extracted inp data of Scenario-642 to csv.
# Extracted inp data of Scenario-643 to csv.
# Extracted inp data of Scenario-644 to csv.
# Extracted inp data of Scenario-645 to csv.
# Extracted inp data of Scenario-646 to csv.
# Extracted inp data of Scenario-647 to csv.
# Extracted inp data of Scenario-648 to csv.
# Extracted inp data of Scenario-649 to csv.
# Extracted inp data of Scenario-650 to csv.
# Extracted inp data of Scenario-651 to csv.
# Extracted inp data of Scenario-652 to csv.
# Extracted inp data of Scenario-653 to csv.
# Extracted inp data of Scenario-654 to csv.
# Extracted inp data of Scenario-655 to csv.
# Extracted inp data of Scenario-656 to csv.
# Extracted inp data of Scenario-657 to csv.
# Extracted inp data of Scenario-658 to csv.
# Extracted inp data of Scenario-659 to csv.
# Extracted inp data of Scenario-660 to csv.
# Extracted inp data of Scenario-661 to csv.
# Extracted inp data of Scenario-662 to csv.
# Extracted inp data of Scenario-663 to csv.
# Extracted inp data of Scenario-664 to csv.
# Extracted inp data of Scenario-665 to csv.
# Extracted inp data of Scenario-666 to csv.
# Extracted inp data of Scenario-667 to csv.
# Extracted inp data of Scenario-668 to csv.
# Extracted inp data of Scenario-669 to csv.
# Extracted inp data of Scenario-670 to csv.
# Extracted inp data of Scenario-671 to csv.
# Extracted inp data of Scenario-672 to csv.
# Extracted inp data of Scenario-673 to csv.
# Extracted inp data of Scenario-674 to csv.
# Extracted inp data of Scenario-675 to csv.
# Extracted inp data of Scenario-676 to csv.
# Extracted inp data of Scenario-677 to csv.
# Extracted inp data of Scenario-678 to csv.
# Extracted inp data of Scenario-679 to csv.
# Extracted inp data of Scenario-680 to csv.
# Extracted inp data of Scenario-681 to csv.
# Extracted inp data of Scenario-682 to csv.
# Extracted inp data of Scenario-683 to csv.
# Extracted inp data of Scenario-684 to csv.
# Extracted inp data of Scenario-685 to csv.
# Extracted inp data of Scenario-686 to csv.
# Extracted inp data of Scenario-687 to csv.
# Extracted inp data of Scenario-688 to csv.
# Extracted inp data of Scenario-689 to csv.
# Extracted inp data of Scenario-690 to csv.
# Extracted inp data of Scenario-691 to csv.
# Extracted inp data of Scenario-692 to csv.
# Extracted inp data of Scenario-693 to csv.
# Extracted inp data of Scenario-694 to csv.
# Extracted inp data of Scenario-695 to csv.
# Extracted inp data of Scenario-696 to csv.
# Extracted inp data of Scenario-697 to csv.
# Extracted inp data of Scenario-698 to csv.
# Extracted inp data of Scenario-699 to csv.
# Extracted inp data of Scenario-700 to csv.
# Extracted inp data of Scenario-701 to csv.
# Extracted inp data of Scenario-702 to csv.
# Extracted inp data of Scenario-703 to csv.
# Extracted inp data of Scenario-704 to csv.
# Extracted inp data of Scenario-705 to csv.
# Extracted inp data of Scenario-706 to csv.
# Extracted inp data of Scenario-707 to csv.
# Extracted inp data of Scenario-708 to csv.
# Extracted inp data of Scenario-709 to csv.
# Extracted inp data of Scenario-710 to csv.
# Extracted inp data of Scenario-711 to csv.
# Extracted inp data of Scenario-712 to csv.
# Extracted inp data of Scenario-713 to csv.
# Extracted inp data of Scenario-714 to csv.
# Extracted inp data of Scenario-715 to csv.
# Extracted inp data of Scenario-716 to csv.
# Extracted inp data of Scenario-717 to csv.
# Extracted inp data of Scenario-718 to csv.
# Extracted inp data of Scenario-719 to csv.
# Extracted inp data of Scenario-720 to csv.
# Extracted inp data of Scenario-721 to csv.
# Extracted inp data of Scenario-722 to csv.
# Extracted inp data of Scenario-723 to csv.
# Extracted inp data of Scenario-724 to csv.
# Extracted inp data of Scenario-725 to csv.
# Extracted inp data of Scenario-726 to csv.
# Extracted inp data of Scenario-727 to csv.
# Extracted inp data of Scenario-728 to csv.
# Extracted inp data of Scenario-729 to csv.
# Extracted inp data of Scenario-730 to csv.
# Extracted inp data of Scenario-731 to csv.
# Extracted inp data of Scenario-732 to csv.
# Extracted inp data of Scenario-733 to csv.
# Extracted inp data of Scenario-734 to csv.
# Extracted inp data of Scenario-735 to csv.
# Extracted inp data of Scenario-736 to csv.
# Extracted inp data of Scenario-737 to csv.
# Extracted inp data of Scenario-738 to csv.
# Extracted inp data of Scenario-739 to csv.
# Extracted inp data of Scenario-740 to csv.
# Extracted inp data of Scenario-741 to csv.
# Extracted inp data of Scenario-742 to csv.
# Extracted inp data of Scenario-743 to csv.
# Extracted inp data of Scenario-744 to csv.
# Extracted inp data of Scenario-745 to csv.
# Extracted inp data of Scenario-746 to csv.
# Extracted inp data of Scenario-747 to csv.
# Extracted inp data of Scenario-748 to csv.
# Extracted inp data of Scenario-749 to csv.
# Extracted inp data of Scenario-750 to csv.
# Extracted inp data of Scenario-751 to csv.
# Extracted inp data of Scenario-752 to csv.
# Extracted inp data of Scenario-753 to csv.
# Extracted inp data of Scenario-754 to csv.
# Extracted inp data of Scenario-755 to csv.
# Extracted inp data of Scenario-756 to csv.
# Extracted inp data of Scenario-757 to csv.
# Extracted inp data of Scenario-758 to csv.
# Extracted inp data of Scenario-759 to csv.
# Extracted inp data of Scenario-760 to csv.
# Extracted inp data of Scenario-761 to csv.
# Extracted inp data of Scenario-762 to csv.
# Extracted inp data of Scenario-763 to csv.
# Extracted inp data of Scenario-764 to csv.
# Extracted inp data of Scenario-765 to csv.
# Extracted inp data of Scenario-766 to csv.
# Extracted inp data of Scenario-767 to csv.
# Extracted inp data of Scenario-768 to csv.
# Extracted inp data of Scenario-769 to csv.
# Extracted inp data of Scenario-770 to csv.
# Extracted inp data of Scenario-771 to csv.
# Extracted inp data of Scenario-772 to csv.
# Extracted inp data of Scenario-773 to csv.
# Extracted inp data of Scenario-774 to csv.
# Extracted inp data of Scenario-775 to csv.
# Extracted inp data of Scenario-776 to csv.
# Extracted inp data of Scenario-777 to csv.
# Extracted inp data of Scenario-778 to csv.
# Extracted inp data of Scenario-779 to csv.
# Extracted inp data of Scenario-780 to csv.
# Extracted inp data of Scenario-781 to csv.
# Extracted inp data of Scenario-782 to csv.
# Extracted inp data of Scenario-783 to csv.
# Extracted inp data of Scenario-784 to csv.
# Extracted inp data of Scenario-785 to csv.
# Extracted inp data of Scenario-786 to csv.
# Extracted inp data of Scenario-787 to csv.
# Extracted inp data of Scenario-788 to csv.
# Extracted inp data of Scenario-789 to csv.
# Extracted inp data of Scenario-790 to csv.
# Extracted inp data of Scenario-791 to csv.
# Extracted inp data of Scenario-792 to csv.
# Extracted inp data of Scenario-793 to csv.
# Extracted inp data of Scenario-794 to csv.
# Extracted inp data of Scenario-795 to csv.
# Extracted inp data of Scenario-796 to csv.
# Extracted inp data of Scenario-797 to csv.
# Extracted inp data of Scenario-798 to csv.
# Extracted inp data of Scenario-799 to csv.
# Extracted inp data of Scenario-800 to csv.
# Extracted inp data of Scenario-801 to csv.
# Extracted inp data of Scenario-802 to csv.
# Extracted inp data of Scenario-803 to csv.
# Extracted inp data of Scenario-804 to csv.
# Extracted inp data of Scenario-805 to csv.
# Extracted inp data of Scenario-806 to csv.
# Extracted inp data of Scenario-807 to csv.
# Extracted inp data of Scenario-808 to csv.
# Extracted inp data of Scenario-809 to csv.
# Extracted inp data of Scenario-810 to csv.
# Extracted inp data of Scenario-811 to csv.
# Extracted inp data of Scenario-812 to csv.
# Extracted inp data of Scenario-813 to csv.
# Extracted inp data of Scenario-814 to csv.
# Extracted inp data of Scenario-815 to csv.
# Extracted inp data of Scenario-816 to csv.
# Extracted inp data of Scenario-817 to csv.
# Extracted inp data of Scenario-818 to csv.
# Extracted inp data of Scenario-819 to csv.
# Extracted inp data of Scenario-820 to csv.
# Extracted inp data of Scenario-821 to csv.
# Extracted inp data of Scenario-822 to csv.
# Extracted inp data of Scenario-823 to csv.
# Extracted inp data of Scenario-824 to csv.
# Extracted inp data of Scenario-825 to csv.
# Extracted inp data of Scenario-826 to csv.
# Extracted inp data of Scenario-827 to csv.
# Extracted inp data of Scenario-828 to csv.
# Extracted inp data of Scenario-829 to csv.
# Extracted inp data of Scenario-830 to csv.
# Extracted inp data of Scenario-831 to csv.
# Extracted inp data of Scenario-832 to csv.
# Extracted inp data of Scenario-833 to csv.
# Extracted inp data of Scenario-834 to csv.
# Extracted inp data of Scenario-835 to csv.
# Extracted inp data of Scenario-836 to csv.
# Extracted inp data of Scenario-837 to csv.
# Extracted inp data of Scenario-838 to csv.
# Extracted inp data of Scenario-839 to csv.
# Extracted inp data of Scenario-840 to csv.
# Extracted inp data of Scenario-841 to csv.
# Extracted inp data of Scenario-842 to csv.
# Extracted inp data of Scenario-843 to csv.
# Extracted inp data of Scenario-844 to csv.
# Extracted inp data of Scenario-845 to csv.
# Extracted inp data of Scenario-846 to csv.
# Extracted inp data of Scenario-847 to csv.
# Extracted inp data of Scenario-848 to csv.
# Extracted inp data of Scenario-849 to csv.
# Extracted inp data of Scenario-850 to csv.
# Extracted inp data of Scenario-851 to csv.
# Extracted inp data of Scenario-852 to csv.
# Extracted inp data of Scenario-853 to csv.
# Extracted inp data of Scenario-854 to csv.
# Extracted inp data of Scenario-855 to csv.
# Extracted inp data of Scenario-856 to csv.
# Extracted inp data of Scenario-857 to csv.
# Extracted inp data of Scenario-858 to csv.
# Extracted inp data of Scenario-859 to csv.
# Extracted inp data of Scenario-860 to csv.
# Extracted inp data of Scenario-861 to csv.
# Extracted inp data of Scenario-862 to csv.
# Extracted inp data of Scenario-863 to csv.
# Extracted inp data of Scenario-864 to csv.
# Extracted inp data of Scenario-865 to csv.
# Extracted inp data of Scenario-866 to csv.
# Extracted inp data of Scenario-867 to csv.
# Extracted inp data of Scenario-868 to csv.
# Extracted inp data of Scenario-869 to csv.
# Extracted inp data of Scenario-870 to csv.
# Extracted inp data of Scenario-871 to csv.
# Extracted inp data of Scenario-872 to csv.
# Extracted inp data of Scenario-873 to csv.
# Extracted inp data of Scenario-874 to csv.
# Extracted inp data of Scenario-875 to csv.
# Extracted inp data of Scenario-876 to csv.
# Extracted inp data of Scenario-877 to csv.
# Extracted inp data of Scenario-878 to csv.
# Extracted inp data of Scenario-879 to csv.
# Extracted inp data of Scenario-880 to csv.
# Extracted inp data of Scenario-881 to csv.
# Extracted inp data of Scenario-882 to csv.
# Extracted inp data of Scenario-883 to csv.
# Extracted inp data of Scenario-884 to csv.
# Extracted inp data of Scenario-885 to csv.
# Extracted inp data of Scenario-886 to csv.
# Extracted inp data of Scenario-887 to csv.
# Extracted inp data of Scenario-888 to csv.
# Extracted inp data of Scenario-889 to csv.
# Extracted inp data of Scenario-890 to csv.
# Extracted inp data of Scenario-891 to csv.
# Extracted inp data of Scenario-892 to csv.
# Extracted inp data of Scenario-893 to csv.
# Extracted inp data of Scenario-894 to csv.
# Extracted inp data of Scenario-895 to csv.
# Extracted inp data of Scenario-896 to csv.
# Extracted inp data of Scenario-897 to csv.
# Extracted inp data of Scenario-898 to csv.
# Extracted inp data of Scenario-899 to csv.
# Extracted inp data of Scenario-900 to csv.
# Extracted inp data of Scenario-901 to csv.
# Extracted inp data of Scenario-902 to csv.
# Extracted inp data of Scenario-903 to csv.
# Extracted inp data of Scenario-904 to csv.
# Extracted inp data of Scenario-905 to csv.
# Extracted inp data of Scenario-906 to csv.
# Extracted inp data of Scenario-907 to csv.
# Extracted inp data of Scenario-908 to csv.
# Extracted inp data of Scenario-909 to csv.
# Extracted inp data of Scenario-910 to csv.
# Extracted inp data of Scenario-911 to csv.
# Extracted inp data of Scenario-912 to csv.
# Extracted inp data of Scenario-913 to csv.
# Extracted inp data of Scenario-914 to csv.
# Extracted inp data of Scenario-915 to csv.
# Extracted inp data of Scenario-916 to csv.
# Extracted inp data of Scenario-917 to csv.
# Extracted inp data of Scenario-918 to csv.
# Extracted inp data of Scenario-919 to csv.
# Extracted inp data of Scenario-920 to csv.
# Extracted inp data of Scenario-921 to csv.
# Extracted inp data of Scenario-922 to csv.
# Extracted inp data of Scenario-923 to csv.
# Extracted inp data of Scenario-924 to csv.
# Extracted inp data of Scenario-925 to csv.
# Extracted inp data of Scenario-926 to csv.
# Extracted inp data of Scenario-927 to csv.
# Extracted inp data of Scenario-928 to csv.
# Extracted inp data of Scenario-929 to csv.
# Extracted inp data of Scenario-930 to csv.
# Extracted inp data of Scenario-931 to csv.
# Extracted inp data of Scenario-932 to csv.
# Extracted inp data of Scenario-933 to csv.
# Extracted inp data of Scenario-934 to csv.
# Extracted inp data of Scenario-935 to csv.
# Extracted inp data of Scenario-936 to csv.
# Extracted inp data of Scenario-937 to csv.
# Extracted inp data of Scenario-938 to csv.
# Extracted inp data of Scenario-939 to csv.
# Extracted inp data of Scenario-940 to csv.
# Extracted inp data of Scenario-941 to csv.
# Extracted inp data of Scenario-942 to csv.
# Extracted inp data of Scenario-943 to csv.
# Extracted inp data of Scenario-944 to csv.
# Extracted inp data of Scenario-945 to csv.
# Extracted inp data of Scenario-946 to csv.
# Extracted inp data of Scenario-947 to csv.
# Extracted inp data of Scenario-948 to csv.
# Extracted inp data of Scenario-949 to csv.
# Extracted inp data of Scenario-950 to csv.
# Extracted inp data of Scenario-951 to csv.
# Extracted inp data of Scenario-952 to csv.
# Extracted inp data of Scenario-953 to csv.
# Extracted inp data of Scenario-954 to csv.
# Extracted inp data of Scenario-955 to csv.
# Extracted inp data of Scenario-956 to csv.
# Extracted inp data of Scenario-957 to csv.
# Extracted inp data of Scenario-958 to csv.
# Extracted inp data of Scenario-959 to csv.
# Extracted inp data of Scenario-960 to csv.
# Extracted inp data of Scenario-961 to csv.
# Extracted inp data of Scenario-962 to csv.
# Extracted inp data of Scenario-963 to csv.
# Extracted inp data of Scenario-964 to csv.
# Extracted inp data of Scenario-965 to csv.
# Extracted inp data of Scenario-966 to csv.
# Extracted inp data of Scenario-967 to csv.
# Extracted inp data of Scenario-968 to csv.
# Extracted inp data of Scenario-969 to csv.
# Extracted inp data of Scenario-970 to csv.
# Extracted inp data of Scenario-971 to csv.
# Extracted inp data of Scenario-972 to csv.
# Extracted inp data of Scenario-973 to csv.
# Extracted inp data of Scenario-974 to csv.
# Extracted inp data of Scenario-975 to csv.
# Extracted inp data of Scenario-976 to csv.
# Extracted inp data of Scenario-977 to csv.
# Extracted inp data of Scenario-978 to csv.
# Extracted inp data of Scenario-979 to csv.
# Extracted inp data of Scenario-980 to csv.
# Extracted inp data of Scenario-981 to csv.
# Extracted inp data of Scenario-982 to csv.
# Extracted inp data of Scenario-983 to csv.
# Extracted inp data of Scenario-984 to csv.
# Extracted inp data of Scenario-985 to csv.
# Extracted inp data of Scenario-986 to csv.
# Extracted inp data of Scenario-987 to csv.
# Extracted inp data of Scenario-988 to csv.
# Extracted inp data of Scenario-989 to csv.
# Extracted inp data of Scenario-990 to csv.
# Extracted inp data of Scenario-991 to csv.
# Extracted inp data of Scenario-992 to csv.
# Extracted inp data of Scenario-993 to csv.
# Extracted inp data of Scenario-994 to csv.
# Extracted inp data of Scenario-995 to csv.
# Extracted inp data of Scenario-996 to csv.
# Extracted inp data of Scenario-997 to csv.
# Extracted inp data of Scenario-998 to csv.
# Extracted inp data of Scenario-999 to csv.
