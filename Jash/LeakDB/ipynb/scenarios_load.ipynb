# %%
from water_benchmark_hub.leakdb import LeakDB

db = LeakDB()

trial = db.load_scenarios(scenarios_id=[10], use_net1=False)
# Out:
# c:\Users\Jash\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\_param_validation.py:14: UserWarning: A NumPy version >=1.23.5 and <2.3.0 is required for this version of SciPy (detected version 2.3.4)
#   from scipy.sparse import csr_matrix, issparse
# C:\Users\Jash\AppData\Local\Temp\Hanoi.inp: 9.63kB [00:00, 9.85MB/s]
# C:\Users\Jash\AppData\Local\Temp\weekPat_30min.mat: 100%|##########| 622/622 [00:00<?, ?B/s]
# C:\Users\Jash\AppData\Local\Temp\yearOffset_30min.mat: 100%|##########| 281/281 [00:00<?, ?B/s]

# %%
trial

# %%
type(trial)
# Out:
# list

# %%
data = trial[0]
type(data)
# Out:
# epyt_flow.simulation.scenario_config.ScenarioConfig

# %%
data.get_attributes()
# Out:
# {'f_inp_in': 'C:\\Users\\Jash\\AppData\\Local\\Temp\\Hanoi_LeakDB_ID=10.inp',
#  'f_msx_in': None,
#  'general_params': {'simulation_duration': 31536000,
#   'hydraulic_time_step': 1800,
#   'reporting_time_step': 1800},
#  'sensor_config': <epyt_flow.simulation.sensor_config.SensorConfig at 0x12043409750>,
#  'memory_consumption_estimate': None,
#  'custom_controls': [],
#  'simple_controls': [],
#  'complex_controls': [],
#  'sensor_noise': None,
#  'model_uncertainty': <epyt_flow.uncertainty.model_uncertainty.ModelUncertainty at 0x12043408310>,
#  'system_events': [],
#  'sensor_reading_events': []}
